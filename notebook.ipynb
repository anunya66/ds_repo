# %% [markdown]
# # Notebook: Model Inspection & Responsible AI

# %%
# 1) Load model
import pickle
p = '/mnt/data/new_catboost_model.pkl'
try:
    with open(p,'rb') as f:
        m = pickle.load(f)
    print('Loaded', type(m))
except Exception as e:
    print('Failed to load:', e)

# %% [markdown]
# ## 2) Evaluate on a test set (if available)
#
# Provide your test CSV and compute metrics: accuracy, AUC, confusion matrix.

# %% [markdown]
# ## 3) SHAP explanations
#
# Install `shap` and compute explanations for sample inputs.
